# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = 'data/dat_0.npz'
data = np.load(filename)

# %%
print(data.files)
# Out:
# ['sample_freq', 'start_f_GHz', 'stop_f_GHz', 'ramp_time_ms', 'ramp_samples', 'total_samples', 'time_axis', 'nfft', 'freq_axis', 'range_axis', 'voltage', 'power']

# %%
voltage = data['voltage']
time = data['time_axis']

# %%
plt.plot(time.ravel(), voltage.ravel())
