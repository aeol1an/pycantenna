# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = 'RR2_0.npz'
data = np.load(filename)

# %%
data.keys()
# Out:
# KeysView(NpzFile 'RR2_0.npz' with keys: voltage, range_doppler, start_f_GHz, stop_f_GHz, ramp_time_ms...)

# %%
voltage = data['voltage']

# %%
plt.pcolor(data['range_doppler'])
